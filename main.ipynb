# %%
#CONFIG INICIAL

import requests
import pandas as pd
import os
import time

BASE_URL = "https://dadosabertos.camara.leg.br/api/v2"
HEADERS = {"accept": "application/json"}
RAW_DIR = "dados/raw"
os.makedirs(RAW_DIR, exist_ok=True)

def get_json(url, params=None, retries=3):
    for tentativa in range(retries):
        try:
            response = requests.get(url, headers=HEADERS, params=params)
            if response.status_code == 200:
                return response.json()
            else:
                print(f"[ERRO] Status {response.status_code} - {url}")
        except Exception as e:
            print(f"[EXCEÇÃO] {e}")
        return None

# %%
# 1. Deputados
def get_deputados(legislatura):
    print(f"[INICIANDO] Coleta de deputados da legislatura {legislatura}...")
    url = f"{BASE_URL}/deputados"
    data = get_json(url, {"itens": 1000, "idLegislatura": legislatura})
    
    if data and "dados" in data:
        df = pd.DataFrame(data["dados"])
        path = os.path.join(RAW_DIR, f"deputados_legislatura_{legislatura}.csv")
        df.to_csv(path, index=False)
        print(f"[FINALIZADO] {len(df)} deputados salvos em '{path}'")
        return df
    else:
        print("[ERRO] Nenhum dado retornado.")
        return pd.DataFrame()

# %%
df_deputados = get_deputados(57)
df_deputados.head()
# Out:
# [INICIANDO] Coleta de deputados da legislatura 57...
# [FINALIZADO] 673 deputados salvos em 'dados/raw/deputados_legislatura_57.csv'
#        id                                                uri             nome  \
# 0  220593  https://dadosabertos.camara.leg.br/api/v2/depu...   Abilio Brunini
# 1  204379  https://dadosabertos.camara.leg.br/api/v2/depu...   Acácio Favacho
# 2  220714  https://dadosabertos.camara.leg.br/api/v2/depu...      Adail Filho
# 3  221328  https://dadosabertos.camara.leg.br/api/v2/depu...  Adilson Barroso
# 4  204560  https://dadosabertos.camara.leg.br/api/v2/depu...     Adolfo Viana
#
#    siglaPartido                                         uriPartido siglaUf  \
# 0            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 1           MDB  https://dadosabertos.camara.leg.br/api/v2/part...      AP
# 2  REPUBLICANOS  https://dadosabertos.camara.leg.br/api/v2/part...      AM
# 3            PL  https://dadosabertos.camara.leg.br/api/v2/part...      SP
# 4          PSDB  https://dadosabertos.camara.leg.br/api/v2/part...      BA
#
#    idLegislatura                                            urlFoto  \
# 0             57  https://www.camara.leg.br/internet/deputado/ba...
# 1             57  https://www.camara.leg.br/internet/deputado/ba...
# 2             57  https://www.camara.leg.br/internet/deputado/ba...
# 3             57  https://www.camara.leg.br/internet/deputado/ba...
# 4             57  https://www.camara.leg.br/internet/deputado/ba...
#
#                               email
# 0                              None
# 1   dep.acaciofavacho@camara.leg.br
# 2      dep.adailfilho@camara.leg.br
# 3  dep.adilsonbarroso@camara.leg.br
# 4     dep.adolfoviana@camara.leg.br

# %%
# 2. Partidos
def get_partidos():
    print("[INICIANDO] Coleta de partidos...")
    url = f"{BASE_URL}/partidos"
    data = get_json(url)
    
    if data and "dados" in data:
        df = pd.DataFrame(data["dados"])
        path = os.path.join(RAW_DIR, "partidos.csv")
        df.to_csv(path, index=False)
        print(f"[FINALIZADO] {len(df)} partidos salvos em '{path}'")
        return df
    else:
        print("[ERRO] Nenhum partido encontrado.")
        return pd.DataFrame()

# %%
df_partidos = get_partidos()
df_partidos.head()
# Out:
# [INICIANDO] Coleta de partidos...
# [FINALIZADO] 15 partidos salvos em 'dados/raw\partidos.csv'
#       id      sigla                              nome  \
# 0  36898     AVANTE                            Avante
# 1  37905  CIDADANIA                         Cidadania
# 2  36899        MDB  Movimento Democrático Brasileiro
# 3  37901       NOVO                      Partido Novo
# 4  36779      PCdoB       Partido Comunista do Brasil
#
#                                                  uri
# 0  https://dadosabertos.camara.leg.br/api/v2/part...
# 1  https://dadosabertos.camara.leg.br/api/v2/part...
# 2  https://dadosabertos.camara.leg.br/api/v2/part...
# 3  https://dadosabertos.camara.leg.br/api/v2/part...
# 4  https://dadosabertos.camara.leg.br/api/v2/part...

# %%
# 3. Despesas por deputado
def get_despesas_deputados(ano):
    print(f"[INICIANDO] Coleta de despesas dos deputados para o ano {ano}...")

    path_deputados = os.path.join(RAW_DIR, "deputados.csv")
    if not os.path.exists(path_deputados):
        print("[ERRO] Arquivo de deputados não encontrado. Rode primeiro a coleta de deputados.")
        return pd.DataFrame()
    
    deputados_df = pd.read_csv(path_deputados)
    despesas_total = []

    for i, row in deputados_df.iterrows():
        dep_id = row['id']
        dep_nome = row['nome']
        pagina = 1

        while True:
            url = f"{BASE_URL}/deputados/{dep_id}/despesas"
            params = {"ano": ano, "pagina": pagina, "itens": 100}
            data = get_json(url, params)

            if not data or "dados" not in data or not data["dados"]:
                break

            for item in data["dados"]:
                despesas_total.append({
                    "id_deputado": dep_id,
                    "nome_deputado": dep_nome,
                    "tipo_despesa": item.get("tipoDespesa"),
                    "fornecedor": item.get("nomeFornecedor"),
                    "valor": item.get("valorDocumento"),
                    "data": item.get("dataDocumento"),
                    "documento": item.get("numDocumento")
                })

            pagina += 1
            time.sleep(0.02)  # Para evitar sobrecarregar a API

        if (i+1) % 50 == 0:
            print(f"[INFO] Deputado {i+1}/{len(deputados_df)} processado.")

    df_despesas = pd.DataFrame(despesas_total)
    path_out = os.path.join(RAW_DIR, f"despesas_{ano}.csv")
    df_despesas.to_csv(path_out, index=False)
    print(f"[FINALIZADO] {len(df_despesas)} despesas salvas em '{path_out}'")

    return df_despesas

# %%
df_despesas = get_despesas_deputados(2022)
df_despesas.head()
# Out:
# [INICIANDO] Coleta de despesas dos deputados para o ano 2022...
# [INFO] Deputado 50/513 processado.
# [INFO] Deputado 100/513 processado.
# [INFO] Deputado 150/513 processado.
# [INFO] Deputado 200/513 processado.
# [INFO] Deputado 250/513 processado.
# [INFO] Deputado 300/513 processado.
# [INFO] Deputado 350/513 processado.
# [INFO] Deputado 400/513 processado.
# [INFO] Deputado 450/513 processado.
# [INFO] Deputado 500/513 processado.
# [FINALIZADO] 32 despesas salvas em 'dados/raw/despesas_2022.csv'
#    id_deputado   nome_deputado                                   tipo_despesa  \
# 0       136811     Afonso Hamm  LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 1       136811     Afonso Hamm  LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 2       178835    Afonso Motta           DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 3       109429  Benes Leocádio           DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 4       204507  Carla Zambelli           DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#
#                                      fornecedor   valor                 data  \
# 0                               LIZIANE QUEVEDO  3090.0  2023-02-17T00:00:00
# 1                               LIZIANE QUEVEDO  5610.0  2023-02-17T00:00:00
# 2       NOVA IMPRESSAO GRAFICA E PAPELARIA LTDA  2090.0  2023-02-15T00:00:00
# 3        ELDORADO COMUNICACAO E JORNALISMO LTDA  1500.0  2023-02-09T00:00:00
# 4  ALINE DA SILVA SANTOS NASCIMENTO 35683981840  2000.0  2023-02-10T00:00:00
#
#   documento
# 0       635
# 1       636
# 2      1690
# 3        21
# 4        24

# %%
# 4. Proposições
def get_proposicoes_por_ano(ano):
    print(f"[INICIANDO] Coleta de proposições para o ano {ano}...")
    todas = []
    pagina = 1

    while True:
        params = {"ano": ano, "itens": 100, "pagina": pagina}
        data = get_json(f"{BASE_URL}/proposicoes", params)

        if not data or "dados" not in data or not data["dados"]:
            break

        todas.extend(data["dados"])
        if pagina % 5 == 0:
            print(f"[INFO] Página {pagina} — total até agora: {len(todas)} proposições")
        pagina += 1
        time.sleep(0.02)

    df = pd.DataFrame(todas)
    path = os.path.join(RAW_DIR, f"proposicoes_{ano}.csv")
    df.to_csv(path, index=False)
    print(f"[FINALIZADO] {len(df)} proposições salvas em '{path}'")
    return df

# %%
df_proposicoes = get_proposicoes_por_ano(2023)
df_proposicoes.head()
# Out:
# [INICIANDO] Coleta de proposições para o ano 2023...
# [INFO] Página 5 — total até agora: 500 proposições
# [INFO] Página 10 — total até agora: 1000 proposições
# [INFO] Página 15 — total até agora: 1500 proposições
# [INFO] Página 20 — total até agora: 2000 proposições
# [INFO] Página 25 — total até agora: 2500 proposições
# [INFO] Página 30 — total até agora: 3000 proposições
# [INFO] Página 35 — total até agora: 3500 proposições
# [INFO] Página 40 — total até agora: 4000 proposições
# [INFO] Página 45 — total até agora: 4500 proposições
# [INFO] Página 50 — total até agora: 5000 proposições
# [INFO] Página 55 — total até agora: 5500 proposições
# [INFO] Página 60 — total até agora: 6000 proposições
# [INFO] Página 65 — total até agora: 6500 proposições
# [INFO] Página 70 — total até agora: 7000 proposições
# [INFO] Página 75 — total até agora: 7500 proposições
# [INFO] Página 80 — total até agora: 8000 proposições
# [INFO] Página 85 — total até agora: 8500 proposições
# [INFO] Página 90 — total até agora: 9000 proposições
# [INFO] Página 95 — total até agora: 9500 proposições
# [INFO] Página 100 — total até agora: 10000 proposições
# [INFO] Página 105 — total até agora: 10500 proposições
# [INFO] Página 110 — total até agora: 11000 proposições
# [INFO] Página 115 — total até agora: 11500 proposições
# [INFO] Página 120 — total até agora: 12000 proposições
# [INFO] Página 125 — total até agora: 12500 proposições
# [INFO] Página 130 — total até agora: 13000 proposições
# [INFO] Página 135 — total até agora: 13500 proposições
# [INFO] Página 140 — total até agora: 14000 proposições
# [INFO] Página 145 — total até agora: 14500 proposições
# [INFO] Página 150 — total até agora: 15000 proposições
# [INFO] Página 155 — total até agora: 15500 proposições
# [INFO] Página 160 — total até agora: 16000 proposições
# [INFO] Página 165 — total até agora: 16500 proposições
# [INFO] Página 170 — total até agora: 17000 proposições
# [INFO] Página 175 — total até agora: 17500 proposições
# [INFO] Página 180 — total até agora: 18000 proposições
# [INFO] Página 185 — total até agora: 18500 proposições
# [INFO] Página 190 — total até agora: 19000 proposições
# [INFO] Página 195 — total até agora: 19500 proposições
# [INFO] Página 200 — total até agora: 20000 proposições
# [INFO] Página 205 — total até agora: 20500 proposições
# [INFO] Página 210 — total até agora: 21000 proposições
# [INFO] Página 215 — total até agora: 21500 proposições
# [INFO] Página 220 — total até agora: 22000 proposições
# [INFO] Página 225 — total até agora: 22500 proposições
# [ERRO] Status 504 - https://dadosabertos.camara.leg.br/api/v2/proposicoes
# [FINALIZADO] 22900 proposições salvas em 'dados/raw\proposicoes_2023.csv'
#         id                                                uri siglaTipo  \
# 0   618609  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 1  1197773  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 2  1198010  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 3  2074843  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 4  2115253  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
#
#    codTipo  numero   ano                                             ementa
# 0      139    6155  2023  Institui o dia 25 de julho como o "Dia Naciona...
# 1      139    4015  2023  Altera o art. 121 do Decreto-Lei nº 2.848, de ...
# 2      139    2234  2023  Altera redação de dispositivos do artigo 4° da...
# 3      139    6064  2023  Dispõe sobre direito a dano moral e concessão ...
# 4      139    2721  2023  Dispõe sobre a prestação de serviços postais a...

# %% [markdown]
# AQUI NO MEIO SERIA INTERESSANTE ADICIONAR UM TRATAMENTO NO ARQUIVO proposicoes_2023, POIS A CÉLULA ABAIXO UTILIZA ESSE ARQUIVO COMO INPUT

# %%
# 5. Detalhes proposições
from concurrent.futures import ThreadPoolExecutor, as_completed

def get_votacoes_por_proposicoes_parallel(ano):
    print(f"[INICIANDO] Coleta paralela de votações por proposições do ano {ano}...")
    
    path = os.path.join(RAW_DIR, f"proposicoes_{ano}.csv")
    if not os.path.exists(path):
        print("[ERRO] Arquivo de proposições não encontrado.")
        return pd.DataFrame()

    proposicoes = pd.read_csv(path)
    todas_votacoes = []

    def fetch_votacoes(prop_id):
        url = f"{BASE_URL}/proposicoes/{prop_id}/votacoes"
        data = get_json(url)
        if data and "dados" in data:
            for voto in data["dados"]:
                voto["id_proposicao"] = prop_id
            return data["dados"]
        return []

    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(fetch_votacoes, prop_id) for prop_id in proposicoes['id']]
        
        for i, future in enumerate(as_completed(futures), start=1):
            try:
                todas_votacoes.extend(future.result())
            except Exception as e:
                print(f"[ERRO] ao processar futura votação: {e}")
            
            if i % 100 == 0:
                print(f"[INFO] Proposição {i}/{len(proposicoes)} processada")

    df = pd.DataFrame(todas_votacoes)
    path_out = os.path.join(RAW_DIR, f"votacoes_proposicoes_{ano}.csv")
    df.to_csv(path_out, index=False)
    print(f"[FINALIZADO] {len(df)} votações salvas em '{path_out}'")
    return df

# %%
df_votacoes = get_votacoes_por_proposicoes_parallel(2023)
df_votacoes.head()
# Out:
# [INICIANDO] Coleta paralela de votações por proposições do ano 2023...
# [INFO] Proposição 100/22900 processada
# [INFO] Proposição 200/22900 processada
# [INFO] Proposição 300/22900 processada
# [INFO] Proposição 400/22900 processada
# [INFO] Proposição 500/22900 processada
# [INFO] Proposição 600/22900 processada
# [INFO] Proposição 700/22900 processada
# [INFO] Proposição 800/22900 processada
# [INFO] Proposição 900/22900 processada
# [INFO] Proposição 1000/22900 processada
# [INFO] Proposição 1100/22900 processada
# [INFO] Proposição 1200/22900 processada
# [INFO] Proposição 1300/22900 processada
# [INFO] Proposição 1400/22900 processada
# [INFO] Proposição 1500/22900 processada
# [INFO] Proposição 1600/22900 processada
# [INFO] Proposição 1700/22900 processada
# [INFO] Proposição 1800/22900 processada
# [INFO] Proposição 1900/22900 processada
# [INFO] Proposição 2000/22900 processada
# [INFO] Proposição 2100/22900 processada
# [INFO] Proposição 2200/22900 processada
# [INFO] Proposição 2300/22900 processada
# [INFO] Proposição 2400/22900 processada
# [INFO] Proposição 2500/22900 processada
# [INFO] Proposição 2600/22900 processada
# [INFO] Proposição 2700/22900 processada
# [INFO] Proposição 2800/22900 processada
# [INFO] Proposição 2900/22900 processada
# [INFO] Proposição 3000/22900 processada
# [INFO] Proposição 3100/22900 processada
# [INFO] Proposição 3200/22900 processada
# [INFO] Proposição 3300/22900 processada
# [INFO] Proposição 3400/22900 processada
# [INFO] Proposição 3500/22900 processada
# [INFO] Proposição 3600/22900 processada
# [INFO] Proposição 3700/22900 processada
# [INFO] Proposição 3800/22900 processada
# [INFO] Proposição 3900/22900 processada
# [INFO] Proposição 4000/22900 processada
# [INFO] Proposição 4100/22900 processada
# [INFO] Proposição 4200/22900 processada
# [INFO] Proposição 4300/22900 processada
# [INFO] Proposição 4400/22900 processada
# [INFO] Proposição 4500/22900 processada
# [INFO] Proposição 4600/22900 processada
# [INFO] Proposição 4700/22900 processada
# [INFO] Proposição 4800/22900 processada
# [INFO] Proposição 4900/22900 processada
# [INFO] Proposição 5000/22900 processada
# [INFO] Proposição 5100/22900 processada
# [INFO] Proposição 5200/22900 processada
# [INFO] Proposição 5300/22900 processada
# [INFO] Proposição 5400/22900 processada
# [INFO] Proposição 5500/22900 processada
# [INFO] Proposição 5600/22900 processada
# [INFO] Proposição 5700/22900 processada
# [INFO] Proposição 5800/22900 processada
# [INFO] Proposição 5900/22900 processada
# [INFO] Proposição 6000/22900 processada
# [INFO] Proposição 6100/22900 processada
# [INFO] Proposição 6200/22900 processada
# [INFO] Proposição 6300/22900 processada
# [INFO] Proposição 6400/22900 processada
# [INFO] Proposição 6500/22900 processada
# [INFO] Proposição 6600/22900 processada
# [INFO] Proposição 6700/22900 processada
# [INFO] Proposição 6800/22900 processada
# [INFO] Proposição 6900/22900 processada
# [INFO] Proposição 7000/22900 processada
# [INFO] Proposição 7100/22900 processada
# [INFO] Proposição 7200/22900 processada
# [INFO] Proposição 7300/22900 processada
# [INFO] Proposição 7400/22900 processada
# [INFO] Proposição 7500/22900 processada
# [INFO] Proposição 7600/22900 processada
# [INFO] Proposição 7700/22900 processada
# [INFO] Proposição 7800/22900 processada
# [INFO] Proposição 7900/22900 processada
# [INFO] Proposição 8000/22900 processada
# [INFO] Proposição 8100/22900 processada
# [INFO] Proposição 8200/22900 processada
# [INFO] Proposição 8300/22900 processada
# [INFO] Proposição 8400/22900 processada
# [INFO] Proposição 8500/22900 processada
# [INFO] Proposição 8600/22900 processada
# [INFO] Proposição 8700/22900 processada
# [INFO] Proposição 8800/22900 processada
# [INFO] Proposição 8900/22900 processada
# [INFO] Proposição 9000/22900 processada
# [INFO] Proposição 9100/22900 processada
# [INFO] Proposição 9200/22900 processada
# [INFO] Proposição 9300/22900 processada
# [INFO] Proposição 9400/22900 processada
# [INFO] Proposição 9500/22900 processada
# [INFO] Proposição 9600/22900 processada
# [INFO] Proposição 9700/22900 processada
# [INFO] Proposição 9800/22900 processada
# [INFO] Proposição 9900/22900 processada
# [INFO] Proposição 10000/22900 processada
# [INFO] Proposição 10100/22900 processada
# [INFO] Proposição 10200/22900 processada
# [INFO] Proposição 10300/22900 processada
# [INFO] Proposição 10400/22900 processada
# [INFO] Proposição 10500/22900 processada
# [INFO] Proposição 10600/22900 processada
# [INFO] Proposição 10700/22900 processada
# [INFO] Proposição 10800/22900 processada
# [INFO] Proposição 10900/22900 processada
# [INFO] Proposição 11000/22900 processada
# [INFO] Proposição 11100/22900 processada
# [INFO] Proposição 11200/22900 processada
# [INFO] Proposição 11300/22900 processada
# [INFO] Proposição 11400/22900 processada
# [INFO] Proposição 11500/22900 processada
# [INFO] Proposição 11600/22900 processada
# [INFO] Proposição 11700/22900 processada
# [INFO] Proposição 11800/22900 processada
# [INFO] Proposição 11900/22900 processada
# [INFO] Proposição 12000/22900 processada
# [INFO] Proposição 12100/22900 processada
# [INFO] Proposição 12200/22900 processada
# [INFO] Proposição 12300/22900 processada
# [INFO] Proposição 12400/22900 processada
# [INFO] Proposição 12500/22900 processada
# [INFO] Proposição 12600/22900 processada
# [INFO] Proposição 12700/22900 processada
# [INFO] Proposição 12800/22900 processada
# [INFO] Proposição 12900/22900 processada
# [INFO] Proposição 13000/22900 processada
# [ERRO] Status 504 - https://dadosabertos.camara.leg.br/api/v2/proposicoes/2370594/votacoes
# [ERRO] Status 504 - https://dadosabertos.camara.leg.br/api/v2/proposicoes/2370632/votacoes
# [INFO] Proposição 13100/22900 processada
# [INFO] Proposição 13200/22900 processada
# [INFO] Proposição 13300/22900 processada
# [INFO] Proposição 13400/22900 processada
# [INFO] Proposição 13500/22900 processada
# [INFO] Proposição 13600/22900 processada
# [INFO] Proposição 13700/22900 processada
# [INFO] Proposição 13800/22900 processada
# [INFO] Proposição 13900/22900 processada
# [INFO] Proposição 14000/22900 processada
# [INFO] Proposição 14100/22900 processada
# [INFO] Proposição 14200/22900 processada
# [INFO] Proposição 14300/22900 processada
# [INFO] Proposição 14400/22900 processada
# [INFO] Proposição 14500/22900 processada
# [INFO] Proposição 14600/22900 processada
# [ERRO] Status 504 - https://dadosabertos.camara.leg.br/api/v2/proposicoes/2374196/votacoes
# [INFO] Proposição 14700/22900 processada
# [INFO] Proposição 14800/22900 processada
# [INFO] Proposição 14900/22900 processada
# [INFO] Proposição 15000/22900 processada
# [INFO] Proposição 15100/22900 processada
# [INFO] Proposição 15200/22900 processada
# [INFO] Proposição 15300/22900 processada
# [INFO] Proposição 15400/22900 processada
# [INFO] Proposição 15500/22900 processada
# [INFO] Proposição 15600/22900 processada
# [INFO] Proposição 15700/22900 processada
# [INFO] Proposição 15800/22900 processada
# [INFO] Proposição 15900/22900 processada
# [INFO] Proposição 16000/22900 processada
# [INFO] Proposição 16100/22900 processada
# [INFO] Proposição 16200/22900 processada
# [INFO] Proposição 16300/22900 processada
# [INFO] Proposição 16400/22900 processada
# [INFO] Proposição 16500/22900 processada
# [INFO] Proposição 16600/22900 processada
# [INFO] Proposição 16700/22900 processada
# [INFO] Proposição 16800/22900 processada
# [INFO] Proposição 16900/22900 processada
# [INFO] Proposição 17000/22900 processada
# [INFO] Proposição 17100/22900 processada
# [INFO] Proposição 17200/22900 processada
# [INFO] Proposição 17300/22900 processada
# [INFO] Proposição 17400/22900 processada
# [INFO] Proposição 17500/22900 processada
# [INFO] Proposição 17600/22900 processada
# [INFO] Proposição 17700/22900 processada
# [INFO] Proposição 17800/22900 processada
# [INFO] Proposição 17900/22900 processada
# [INFO] Proposição 18000/22900 processada
# [INFO] Proposição 18100/22900 processada
# [INFO] Proposição 18200/22900 processada
# [INFO] Proposição 18300/22900 processada
# [INFO] Proposição 18400/22900 processada
# [INFO] Proposição 18500/22900 processada
# [INFO] Proposição 18600/22900 processada
# [INFO] Proposição 18700/22900 processada
# [INFO] Proposição 18800/22900 processada
# [INFO] Proposição 18900/22900 processada
# [INFO] Proposição 19000/22900 processada
# [INFO] Proposição 19100/22900 processada
# [INFO] Proposição 19200/22900 processada
# [INFO] Proposição 19300/22900 processada
# [INFO] Proposição 19400/22900 processada
# [INFO] Proposição 19500/22900 processada
# [INFO] Proposição 19600/22900 processada
# [INFO] Proposição 19700/22900 processada
# [INFO] Proposição 19800/22900 processada
# [INFO] Proposição 19900/22900 processada
# [INFO] Proposição 20000/22900 processada
# [INFO] Proposição 20100/22900 processada
# [INFO] Proposição 20200/22900 processada
# [INFO] Proposição 20300/22900 processada
# [INFO] Proposição 20400/22900 processada
# [INFO] Proposição 20500/22900 processada
# [INFO] Proposição 20600/22900 processada
# [INFO] Proposição 20700/22900 processada
# [INFO] Proposição 20800/22900 processada
# [INFO] Proposição 20900/22900 processada
# [INFO] Proposição 21000/22900 processada
# [INFO] Proposição 21100/22900 processada
# [INFO] Proposição 21200/22900 processada
# [INFO] Proposição 21300/22900 processada
# [INFO] Proposição 21400/22900 processada
# [INFO] Proposição 21500/22900 processada
# [INFO] Proposição 21600/22900 processada
# [INFO] Proposição 21700/22900 processada
# [INFO] Proposição 21800/22900 processada
# [INFO] Proposição 21900/22900 processada
# [INFO] Proposição 22000/22900 processada
# [INFO] Proposição 22100/22900 processada
# [INFO] Proposição 22200/22900 processada
# [INFO] Proposição 22300/22900 processada
# [INFO] Proposição 22400/22900 processada
# [INFO] Proposição 22500/22900 processada
# [INFO] Proposição 22600/22900 processada
# [INFO] Proposição 22700/22900 processada
# [INFO] Proposição 22800/22900 processada
# [INFO] Proposição 22900/22900 processada
# [FINALIZADO] 8670 votações salvas em 'dados/raw\votacoes_proposicoes_2023.csv'
#            id                                                uri        data  \
# 0  2345493-64  https://dadosabertos.camara.leg.br/api/v2/vota...  2023-05-31
# 1  2345493-62  https://dadosabertos.camara.leg.br/api/v2/vota...  2023-05-31
# 2  2345493-52  https://dadosabertos.camara.leg.br/api/v2/vota...  2023-05-31
# 3  2345493-50  https://dadosabertos.camara.leg.br/api/v2/vota...  2023-05-31
# 4  2345493-47  https://dadosabertos.camara.leg.br/api/v2/vota...  2023-05-31
#
#       dataHoraRegistro siglaOrgao  \
# 0  2023-06-01T00:26:58       PLEN
# 1  2023-06-01T00:26:24       PLEN
# 2  2023-06-01T00:15:40       PLEN
# 3  2023-06-01T00:14:11       PLEN
# 4  2023-05-31T23:56:17       PLEN
#
#                                             uriOrgao  \
# 0  https://dadosabertos.camara.leg.br/api/v2/orga...
# 1  https://dadosabertos.camara.leg.br/api/v2/orga...
# 2  https://dadosabertos.camara.leg.br/api/v2/orga...
# 3  https://dadosabertos.camara.leg.br/api/v2/orga...
# 4  https://dadosabertos.camara.leg.br/api/v2/orga...
#
#                                            uriEvento proposicaoObjeto  \
# 0  https://dadosabertos.camara.leg.br/api/v2/even...             None
# 1  https://dadosabertos.camara.leg.br/api/v2/even...             None
# 2  https://dadosabertos.camara.leg.br/api/v2/even...             None
# 3  https://dadosabertos.camara.leg.br/api/v2/even...             None
# 4  https://dadosabertos.camara.leg.br/api/v2/even...             None
#
#   uriProposicaoObjeto                                          descricao  \
# 0                None  Aprovada a Redação Final assinada pelo Relator...
# 1                None  Aprovadas as Emenda de Redação nºs 2, 3, 4, 5 ...
# 2                None                                 Suprimido o texto.
# 3                None  Rejeitada a Emenda de Comissão nº 14. Sim: 182...
# 4                None  Mantido o texto. Sim: 260; não: 186; abstenção...
#
#    aprovacao  id_proposicao
# 0        1.0        2345493
# 1        1.0        2345493
# 2        NaN        2345493
# 3        0.0        2345493
# 4        NaN        2345493

# %%
# 6. Votos individuais referentes as proposições
from concurrent.futures import ThreadPoolExecutor, as_completed

def get_votos_individuais_proposicoes(ano, max_workers=10):
    print(f"[INICIANDO] Coleta de votos individuais das proposições de {ano}...")

    path_votacoes = os.path.join(RAW_DIR, f"votacoes_proposicoes_{ano}.csv")
    if not os.path.exists(path_votacoes):
        print(f"[ERRO] Arquivo votacoes_proposicoes_{ano}.csv não encontrado.")
        return pd.DataFrame()

    votacoes_df = pd.read_csv(path_votacoes)

    # Extrai apenas o número da votação da URI (removendo sufixos como -64)
    votacoes_df["votacao_id"] = votacoes_df["uri"].apply(lambda x: x.split("/")[-1])
    votacao_ids = votacoes_df["votacao_id"].unique()

    def fetch_votos(votacao_id):
        url = f"{BASE_URL}/votacoes/{votacao_id}/votos"
        data = get_json(url)
        if data and "dados" in data:
            df = pd.DataFrame(data["dados"])
            df["id_votacao"] = votacao_id
            return df
        return pd.DataFrame()

    votos_total = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_votos, vid) for vid in votacao_ids]
        for i, future in enumerate(as_completed(futures), 1):
            df = future.result()
            if not df.empty:
                votos_total.append(df)
            if i % 100 == 0:
                print(f"[INFO] Votação {i}/{len(votacao_ids)} processada")

    if votos_total:
        final_df = pd.concat(votos_total, ignore_index=True)
        output_path = os.path.join(RAW_DIR, f"votos_individuais_proposicoes_{ano}.csv")
        final_df.to_csv(output_path, index=False)
        print(f"[FINALIZADO] {len(final_df)} votos salvos em '{output_path}'")
        return final_df
    else:
        print("[AVISO] Nenhum voto encontrado.")
        return pd.DataFrame()

# %%
df_votos = get_votos_individuais_proposicoes(2023)
df_votos.head()
# Out:
# [INICIANDO] Coleta de votos individuais das proposições de 2023...
# [INFO] Votação 100/7809 processada
# [INFO] Votação 200/7809 processada
# [INFO] Votação 300/7809 processada
# [INFO] Votação 400/7809 processada
# [INFO] Votação 500/7809 processada
# [INFO] Votação 600/7809 processada
# [INFO] Votação 700/7809 processada
# [INFO] Votação 800/7809 processada
# [INFO] Votação 900/7809 processada
# [INFO] Votação 1000/7809 processada
# [INFO] Votação 1100/7809 processada
# [INFO] Votação 1200/7809 processada
# [INFO] Votação 1300/7809 processada
# [INFO] Votação 1400/7809 processada
# [INFO] Votação 1500/7809 processada
# [INFO] Votação 1600/7809 processada
# [INFO] Votação 1700/7809 processada
# [INFO] Votação 1800/7809 processada
# [INFO] Votação 1900/7809 processada
# [INFO] Votação 2000/7809 processada
# [INFO] Votação 2100/7809 processada
# [INFO] Votação 2200/7809 processada
# [INFO] Votação 2300/7809 processada
# [INFO] Votação 2400/7809 processada
# [INFO] Votação 2500/7809 processada
# [INFO] Votação 2600/7809 processada
# [INFO] Votação 2700/7809 processada
# [INFO] Votação 2800/7809 processada
# [INFO] Votação 2900/7809 processada
# [INFO] Votação 3000/7809 processada
# [INFO] Votação 3100/7809 processada
# [INFO] Votação 3200/7809 processada
# [INFO] Votação 3300/7809 processada
# [INFO] Votação 3400/7809 processada
# [INFO] Votação 3500/7809 processada
# [INFO] Votação 3600/7809 processada
# [INFO] Votação 3700/7809 processada
# [INFO] Votação 3800/7809 processada
# [INFO] Votação 3900/7809 processada
# [INFO] Votação 4000/7809 processada
# [INFO] Votação 4100/7809 processada
# [INFO] Votação 4200/7809 processada
# [INFO] Votação 4300/7809 processada
# [INFO] Votação 4400/7809 processada
# [INFO] Votação 4500/7809 processada
# [INFO] Votação 4600/7809 processada
# [INFO] Votação 4700/7809 processada
# [INFO] Votação 4800/7809 processada
# [INFO] Votação 4900/7809 processada
# [INFO] Votação 5000/7809 processada
# [INFO] Votação 5100/7809 processada
# [INFO] Votação 5200/7809 processada
# [INFO] Votação 5300/7809 processada
# [INFO] Votação 5400/7809 processada
# [INFO] Votação 5500/7809 processada
# [INFO] Votação 5600/7809 processada
# [INFO] Votação 5700/7809 processada
# [INFO] Votação 5800/7809 processada
# [INFO] Votação 5900/7809 processada
# [INFO] Votação 6000/7809 processada
# [INFO] Votação 6100/7809 processada
# [INFO] Votação 6200/7809 processada
# [INFO] Votação 6300/7809 processada
# [INFO] Votação 6400/7809 processada
# [INFO] Votação 6500/7809 processada
# [INFO] Votação 6600/7809 processada
# [INFO] Votação 6700/7809 processada
# [INFO] Votação 6800/7809 processada
# [INFO] Votação 6900/7809 processada
# [INFO] Votação 7000/7809 processada
# [INFO] Votação 7100/7809 processada
# [INFO] Votação 7200/7809 processada
# [INFO] Votação 7300/7809 processada
# [INFO] Votação 7400/7809 processada
# [INFO] Votação 7500/7809 processada
# [INFO] Votação 7600/7809 processada
# [INFO] Votação 7700/7809 processada
# [INFO] Votação 7800/7809 processada
# [FINALIZADO] 95323 votos salvos em 'dados/raw\votos_individuais_proposicoes_2023.csv'
#   tipoVoto     dataRegistroVoto  \
# 0      Sim  2023-06-01T00:12:10
# 1      Não  2023-06-01T00:12:09
# 2      Sim  2023-06-01T00:12:05
# 3      Sim  2023-06-01T00:11:55
# 4      Sim  2023-06-01T00:11:54
#
#                                            deputado_  id_votacao
# 0  {'id': 220666, 'uri': 'https://dadosabertos.ca...  2345493-50
# 1  {'id': 178896, 'uri': 'https://dadosabertos.ca...  2345493-50
# 2  {'id': 220689, 'uri': 'https://dadosabertos.ca...  2345493-50
# 3  {'id': 178954, 'uri': 'https://dadosabertos.ca...  2345493-50
# 4  {'id': 204563, 'uri': 'https://dadosabertos.ca...  2345493-50

# %%
# 7. Orientações partidárias por votação
from concurrent.futures import ThreadPoolExecutor, as_completed

def fetch_orientacoes(votacao_id):
    url = f"{BASE_URL}/votacoes/{votacao_id}/orientacoes"
    data = get_json(url)
    orientacoes = []

    if data and "dados" in data:
        for item in data["dados"]:
            item["id_votacao"] = votacao_id
            orientacoes.append(item)

    return orientacoes

def get_orientacoes_por_proposicoes(ano, max_workers=10):
    print(f"[INICIANDO] Coleta de orientações por votação de proposições do ano {ano}...")

    path_votacoes = os.path.join(RAW_DIR, f"votacoes_proposicoes_{ano}.csv")
    if not os.path.exists(path_votacoes):
        print("[ERRO] Arquivo de votações por proposição não encontrado.")
        return pd.DataFrame()

    votacoes_df = pd.read_csv(path_votacoes)
    votacoes_df["votacao_id"] = votacoes_df["uri"].apply(lambda x: x.split("/")[-1])
    votacao_ids = votacoes_df["votacao_id"].unique().tolist()

    todas_orientacoes = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_orientacoes, vid) for vid in votacao_ids]

        for i, future in enumerate(as_completed(futures), 1):
            orientacoes = future.result()
            todas_orientacoes.extend(orientacoes)
            if i % 100 == 0:
                print(f"[INFO] Votação {i}/{len(votacao_ids)} processada")

    df = pd.DataFrame(todas_orientacoes)
    output_path = os.path.join(RAW_DIR, f"orientacoes_partidarias_proposicoes_{ano}.csv")
    df.to_csv(output_path, index=False)
    print(f"[FINALIZADO] {len(df)} orientações salvas em '{output_path}'")
    return df

# %%
df_orientacoes = get_orientacoes_por_proposicoes(2023)
df_orientacoes.head()
# Out:
# [INICIANDO] Coleta de orientações por votação de proposições do ano 2023...
# [INFO] Votação 100/7809 processada
# [INFO] Votação 200/7809 processada
# [INFO] Votação 300/7809 processada
# [INFO] Votação 400/7809 processada
# [INFO] Votação 500/7809 processada
# [INFO] Votação 600/7809 processada
# [INFO] Votação 700/7809 processada
# [INFO] Votação 800/7809 processada
# [INFO] Votação 900/7809 processada
# [INFO] Votação 1000/7809 processada
# [INFO] Votação 1100/7809 processada
# [INFO] Votação 1200/7809 processada
# [INFO] Votação 1300/7809 processada
# [INFO] Votação 1400/7809 processada
# [INFO] Votação 1500/7809 processada
# [INFO] Votação 1600/7809 processada
# [INFO] Votação 1700/7809 processada
# [INFO] Votação 1800/7809 processada
# [INFO] Votação 1900/7809 processada
# [INFO] Votação 2000/7809 processada
# [INFO] Votação 2100/7809 processada
# [INFO] Votação 2200/7809 processada
# [INFO] Votação 2300/7809 processada
# [INFO] Votação 2400/7809 processada
# [INFO] Votação 2500/7809 processada
# [INFO] Votação 2600/7809 processada
# [INFO] Votação 2700/7809 processada
# [INFO] Votação 2800/7809 processada
# [INFO] Votação 2900/7809 processada
# [INFO] Votação 3000/7809 processada
# [INFO] Votação 3100/7809 processada
# [INFO] Votação 3200/7809 processada
# [INFO] Votação 3300/7809 processada
# [INFO] Votação 3400/7809 processada
# [INFO] Votação 3500/7809 processada
# [INFO] Votação 3600/7809 processada
# [INFO] Votação 3700/7809 processada
# [INFO] Votação 3800/7809 processada
# [INFO] Votação 3900/7809 processada
# [INFO] Votação 4000/7809 processada
# [INFO] Votação 4100/7809 processada
# [INFO] Votação 4200/7809 processada
# [INFO] Votação 4300/7809 processada
# [INFO] Votação 4400/7809 processada
# [INFO] Votação 4500/7809 processada
# [INFO] Votação 4600/7809 processada
# [INFO] Votação 4700/7809 processada
# [INFO] Votação 4800/7809 processada
# [INFO] Votação 4900/7809 processada
# [INFO] Votação 5000/7809 processada
# [INFO] Votação 5100/7809 processada
# [INFO] Votação 5200/7809 processada
# [INFO] Votação 5300/7809 processada
# [INFO] Votação 5400/7809 processada
# [INFO] Votação 5500/7809 processada
# [INFO] Votação 5600/7809 processada
# [INFO] Votação 5700/7809 processada
# [INFO] Votação 5800/7809 processada
# [INFO] Votação 5900/7809 processada
# [INFO] Votação 6000/7809 processada
# [INFO] Votação 6100/7809 processada
# [INFO] Votação 6200/7809 processada
# [INFO] Votação 6300/7809 processada
# [INFO] Votação 6400/7809 processada
# [INFO] Votação 6500/7809 processada
# [INFO] Votação 6600/7809 processada
# [INFO] Votação 6700/7809 processada
# [INFO] Votação 6800/7809 processada
# [INFO] Votação 6900/7809 processada
# [INFO] Votação 7000/7809 processada
# [INFO] Votação 7100/7809 processada
# [INFO] Votação 7200/7809 processada
# [INFO] Votação 7300/7809 processada
# [INFO] Votação 7400/7809 processada
# [INFO] Votação 7500/7809 processada
# [INFO] Votação 7600/7809 processada
# [INFO] Votação 7700/7809 processada
# [INFO] Votação 7800/7809 processada
# [FINALIZADO] 2931 orientações salvas em 'dados/raw\orientacoes_partidarias_proposicoes_2023.csv'
#   orientacaoVoto codTipoLideranca      siglaPartidoBloco  codPartidoBloco  \
# 0            Sim                B                Maioria              NaN
# 1            Sim                B          Fdr PSOL-REDE              NaN
# 2            Sim                B  Bl UniPpFdrPsdbCid...              NaN
# 3            Não                P                     PL          37906.0
# 4            Sim                B        Fdr PT-PCdoB-PV              NaN
#
#                                      uriPartidoBloco  id_votacao
# 0                                               None  2345493-35
# 1                                               None  2345493-35
# 2                                               None  2345493-35
# 3  https://dadosabertos.camara.leg.br/api/v2/part...  2345493-35
# 4                                               None  2345493-35

# %%
# 8. Autores das proposições
def fetch_autores(prop_id):
    url = f"{BASE_URL}/proposicoes/{prop_id}/autores"
    data = get_json(url)
    autores = []

    if data and "dados" in data:
        for item in data["dados"]:
            item["id_proposicao"] = prop_id
            autores.append(item)

    return autores

def get_autores_por_proposicoes(ano, max_workers=10):
    print(f"[INICIANDO] Coleta de autores das proposições do ano {ano}...")

    path_props = os.path.join(RAW_DIR, f"proposicoes_{ano}.csv")
    if not os.path.exists(path_props):
        print("[ERRO] Arquivo de proposições não encontrado.")
        return pd.DataFrame()

    proposicoes_df = pd.read_csv(path_props)
    prop_ids = proposicoes_df["id"].unique().tolist()

    todos_autores = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_autores, pid) for pid in prop_ids]

        for i, future in enumerate(as_completed(futures), 1):
            autores = future.result()
            todos_autores.extend(autores)
            if i % 100 == 0:
                print(f"[INFO] Proposição {i}/{len(prop_ids)} processada")

    df = pd.DataFrame(todos_autores)
    output_path = os.path.join(RAW_DIR, f"autores_proposicoes_{ano}.csv")
    df.to_csv(output_path, index=False)
    print(f"[FINALIZADO] {len(df)} autores salvos em '{output_path}'")
    return df

# %%
df_autores = get_autores_por_proposicoes(2023)
df_autores.head()
# Out:
# [INICIANDO] Coleta de autores das proposições do ano 2023...
# [INFO] Proposição 100/22900 processada
# [INFO] Proposição 200/22900 processada
# [INFO] Proposição 300/22900 processada
# [INFO] Proposição 400/22900 processada
# [INFO] Proposição 500/22900 processada
# [INFO] Proposição 600/22900 processada
# [INFO] Proposição 700/22900 processada
# [INFO] Proposição 800/22900 processada
# [INFO] Proposição 900/22900 processada
# [INFO] Proposição 1000/22900 processada
# [INFO] Proposição 1100/22900 processada
# [INFO] Proposição 1200/22900 processada
# [INFO] Proposição 1300/22900 processada
# [INFO] Proposição 1400/22900 processada
# [INFO] Proposição 1500/22900 processada
# [INFO] Proposição 1600/22900 processada
# [INFO] Proposição 1700/22900 processada
# [INFO] Proposição 1800/22900 processada
# [INFO] Proposição 1900/22900 processada
# [INFO] Proposição 2000/22900 processada
# [INFO] Proposição 2100/22900 processada
# [INFO] Proposição 2200/22900 processada
# [INFO] Proposição 2300/22900 processada
# [INFO] Proposição 2400/22900 processada
# [INFO] Proposição 2500/22900 processada
# [INFO] Proposição 2600/22900 processada
# [INFO] Proposição 2700/22900 processada
# [INFO] Proposição 2800/22900 processada
# [INFO] Proposição 2900/22900 processada
# [INFO] Proposição 3000/22900 processada
# [INFO] Proposição 3100/22900 processada
# [INFO] Proposição 3200/22900 processada
# [INFO] Proposição 3300/22900 processada
# [INFO] Proposição 3400/22900 processada
# [INFO] Proposição 3500/22900 processada
# [INFO] Proposição 3600/22900 processada
# [INFO] Proposição 3700/22900 processada
# [INFO] Proposição 3800/22900 processada
# [INFO] Proposição 3900/22900 processada
# [INFO] Proposição 4000/22900 processada
# [INFO] Proposição 4100/22900 processada
# [INFO] Proposição 4200/22900 processada
# [INFO] Proposição 4300/22900 processada
# [INFO] Proposição 4400/22900 processada
# [INFO] Proposição 4500/22900 processada
# [INFO] Proposição 4600/22900 processada
# [INFO] Proposição 4700/22900 processada
# [INFO] Proposição 4800/22900 processada
# [INFO] Proposição 4900/22900 processada
# [INFO] Proposição 5000/22900 processada
# [INFO] Proposição 5100/22900 processada
# [INFO] Proposição 5200/22900 processada
# [INFO] Proposição 5300/22900 processada
# [INFO] Proposição 5400/22900 processada
# [INFO] Proposição 5500/22900 processada
# [INFO] Proposição 5600/22900 processada
# [INFO] Proposição 5700/22900 processada
# [INFO] Proposição 5800/22900 processada
# [INFO] Proposição 5900/22900 processada
# [INFO] Proposição 6000/22900 processada
# [INFO] Proposição 6100/22900 processada
# [INFO] Proposição 6200/22900 processada
# [INFO] Proposição 6300/22900 processada
# [INFO] Proposição 6400/22900 processada
# [INFO] Proposição 6500/22900 processada
# [INFO] Proposição 6600/22900 processada
# [INFO] Proposição 6700/22900 processada
# [INFO] Proposição 6800/22900 processada
# [INFO] Proposição 6900/22900 processada
# [INFO] Proposição 7000/22900 processada
# [INFO] Proposição 7100/22900 processada
# [INFO] Proposição 7200/22900 processada
# [INFO] Proposição 7300/22900 processada
# [INFO] Proposição 7400/22900 processada
# [INFO] Proposição 7500/22900 processada
# [INFO] Proposição 7600/22900 processada
# [INFO] Proposição 7700/22900 processada
# [INFO] Proposição 7800/22900 processada
# [INFO] Proposição 7900/22900 processada
# [INFO] Proposição 8000/22900 processada
# [INFO] Proposição 8100/22900 processada
# [INFO] Proposição 8200/22900 processada
# [INFO] Proposição 8300/22900 processada
# [INFO] Proposição 8400/22900 processada
# [INFO] Proposição 8500/22900 processada
# [INFO] Proposição 8600/22900 processada
# [INFO] Proposição 8700/22900 processada
# [INFO] Proposição 8800/22900 processada
# [INFO] Proposição 8900/22900 processada
# [INFO] Proposição 9000/22900 processada
# [INFO] Proposição 9100/22900 processada
# [INFO] Proposição 9200/22900 processada
# [INFO] Proposição 9300/22900 processada
# [INFO] Proposição 9400/22900 processada
# [INFO] Proposição 9500/22900 processada
# [INFO] Proposição 9600/22900 processada
# [INFO] Proposição 9700/22900 processada
# [INFO] Proposição 9800/22900 processada
# [INFO] Proposição 9900/22900 processada
# [INFO] Proposição 10000/22900 processada
# [INFO] Proposição 10100/22900 processada
# [INFO] Proposição 10200/22900 processada
# [INFO] Proposição 10300/22900 processada
# [INFO] Proposição 10400/22900 processada
# [INFO] Proposição 10500/22900 processada
# [INFO] Proposição 10600/22900 processada
# [INFO] Proposição 10700/22900 processada
# [INFO] Proposição 10800/22900 processada
# [INFO] Proposição 10900/22900 processada
# [INFO] Proposição 11000/22900 processada
# [INFO] Proposição 11100/22900 processada
# [INFO] Proposição 11200/22900 processada
# [INFO] Proposição 11300/22900 processada
# [INFO] Proposição 11400/22900 processada
# [INFO] Proposição 11500/22900 processada
# [INFO] Proposição 11600/22900 processada
# [INFO] Proposição 11700/22900 processada
# [INFO] Proposição 11800/22900 processada
# [INFO] Proposição 11900/22900 processada
# [INFO] Proposição 12000/22900 processada
# [INFO] Proposição 12100/22900 processada
# [INFO] Proposição 12200/22900 processada
# [INFO] Proposição 12300/22900 processada
# [INFO] Proposição 12400/22900 processada
# [INFO] Proposição 12500/22900 processada
# [INFO] Proposição 12600/22900 processada
# [INFO] Proposição 12700/22900 processada
# [INFO] Proposição 12800/22900 processada
# [INFO] Proposição 12900/22900 processada
# [INFO] Proposição 13000/22900 processada
# [INFO] Proposição 13100/22900 processada
# [INFO] Proposição 13200/22900 processada
# [INFO] Proposição 13300/22900 processada
# [INFO] Proposição 13400/22900 processada
# [INFO] Proposição 13500/22900 processada
# [INFO] Proposição 13600/22900 processada
# [INFO] Proposição 13700/22900 processada
# [INFO] Proposição 13800/22900 processada
# [INFO] Proposição 13900/22900 processada
# [INFO] Proposição 14000/22900 processada
# [INFO] Proposição 14100/22900 processada
# [INFO] Proposição 14200/22900 processada
# [INFO] Proposição 14300/22900 processada
# [INFO] Proposição 14400/22900 processada
# [INFO] Proposição 14500/22900 processada
# [INFO] Proposição 14600/22900 processada
# [INFO] Proposição 14700/22900 processada
# [INFO] Proposição 14800/22900 processada
# [INFO] Proposição 14900/22900 processada
# [INFO] Proposição 15000/22900 processada
# [INFO] Proposição 15100/22900 processada
# [INFO] Proposição 15200/22900 processada
# [INFO] Proposição 15300/22900 processada
# [INFO] Proposição 15400/22900 processada
# [INFO] Proposição 15500/22900 processada
# [INFO] Proposição 15600/22900 processada
# [INFO] Proposição 15700/22900 processada
# [INFO] Proposição 15800/22900 processada
# [INFO] Proposição 15900/22900 processada
# [INFO] Proposição 16000/22900 processada
# [INFO] Proposição 16100/22900 processada
# [INFO] Proposição 16200/22900 processada
# [INFO] Proposição 16300/22900 processada
# [INFO] Proposição 16400/22900 processada
# [INFO] Proposição 16500/22900 processada
# [INFO] Proposição 16600/22900 processada
# [INFO] Proposição 16700/22900 processada
# [INFO] Proposição 16800/22900 processada
# [INFO] Proposição 16900/22900 processada
# [INFO] Proposição 17000/22900 processada
# [INFO] Proposição 17100/22900 processada
# [INFO] Proposição 17200/22900 processada
# [INFO] Proposição 17300/22900 processada
# [INFO] Proposição 17400/22900 processada
# [INFO] Proposição 17500/22900 processada
# [INFO] Proposição 17600/22900 processada
# [INFO] Proposição 17700/22900 processada
# [INFO] Proposição 17800/22900 processada
# [INFO] Proposição 17900/22900 processada
# [INFO] Proposição 18000/22900 processada
# [INFO] Proposição 18100/22900 processada
# [INFO] Proposição 18200/22900 processada
# [INFO] Proposição 18300/22900 processada
# [INFO] Proposição 18400/22900 processada
# [INFO] Proposição 18500/22900 processada
# [INFO] Proposição 18600/22900 processada
# [INFO] Proposição 18700/22900 processada
# [INFO] Proposição 18800/22900 processada
# [INFO] Proposição 18900/22900 processada
# [INFO] Proposição 19000/22900 processada
# [INFO] Proposição 19100/22900 processada
# [INFO] Proposição 19200/22900 processada
# [INFO] Proposição 19300/22900 processada
# [INFO] Proposição 19400/22900 processada
# [INFO] Proposição 19500/22900 processada
# [INFO] Proposição 19600/22900 processada
# [INFO] Proposição 19700/22900 processada
# [INFO] Proposição 19800/22900 processada
# [INFO] Proposição 19900/22900 processada
# [INFO] Proposição 20000/22900 processada
# [INFO] Proposição 20100/22900 processada
# [INFO] Proposição 20200/22900 processada
# [INFO] Proposição 20300/22900 processada
# [INFO] Proposição 20400/22900 processada
# [INFO] Proposição 20500/22900 processada
# [INFO] Proposição 20600/22900 processada
# [INFO] Proposição 20700/22900 processada
# [INFO] Proposição 20800/22900 processada
# [INFO] Proposição 20900/22900 processada
# [INFO] Proposição 21000/22900 processada
# [INFO] Proposição 21100/22900 processada
# [INFO] Proposição 21200/22900 processada
# [INFO] Proposição 21300/22900 processada
# [INFO] Proposição 21400/22900 processada
# [INFO] Proposição 21500/22900 processada
# [INFO] Proposição 21600/22900 processada
# [INFO] Proposição 21700/22900 processada
# [INFO] Proposição 21800/22900 processada
# [INFO] Proposição 21900/22900 processada
# [INFO] Proposição 22000/22900 processada
# [INFO] Proposição 22100/22900 processada
# [INFO] Proposição 22200/22900 processada
# [INFO] Proposição 22300/22900 processada
# [INFO] Proposição 22400/22900 processada
# [INFO] Proposição 22500/22900 processada
# [INFO] Proposição 22600/22900 processada
# [INFO] Proposição 22700/22900 processada
# [INFO] Proposição 22800/22900 processada
# [INFO] Proposição 22900/22900 processada
# [FINALIZADO] 110971 autores salvos em 'dados/raw\autores_proposicoes_2023.csv'
#                                                  uri             nome  \
# 0  https://dadosabertos.camara.leg.br/api/v2/depu...  Giovani Cherini
# 1  https://dadosabertos.camara.leg.br/api/v2/orga...  Poder Executivo
# 2  https://dadosabertos.camara.leg.br/api/v2/depu...    Mara Gabrilli
# 3  https://dadosabertos.camara.leg.br/api/v2/depu...     Efraim Filho
# 4  https://dadosabertos.camara.leg.br/api/v2/orga...  Poder Executivo
#
#    codTipo                      tipo  ordemAssinatura  proponente  \
# 0    10000               Deputado(a)                1           1
# 1    30000  Órgão do Poder Executivo                1           1
# 2    10000               Deputado(a)                1           1
# 3    10000               Deputado(a)                1           1
# 4    30000  Órgão do Poder Executivo                1           1
#
#    id_proposicao
# 0         618609
# 1        2345493
# 2        2074843
# 3        1198010
# 4        2345487

# %%
# 9. Temas por proposição
def fetch_temas(prop_id):
    url = f"{BASE_URL}/proposicoes/{prop_id}/temas"
    data = get_json(url)
    temas = []

    if data and "dados" in data:
        for item in data["dados"]:
            item["id_proposicao"] = prop_id
            temas.append(item)

    return temas

def get_temas_por_proposicoes(ano, max_workers=10):
    print(f"[INICIANDO] Coleta de temas das proposições do ano {ano}...")

    path_props = os.path.join(RAW_DIR, f"proposicoes_{ano}.csv")
    if not os.path.exists(path_props):
        print("[ERRO] Arquivo de proposições não encontrado.")
        return pd.DataFrame()

    proposicoes_df = pd.read_csv(path_props)
    prop_ids = proposicoes_df["id"].unique().tolist()

    todos_temas = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_temas, pid) for pid in prop_ids]

        for i, future in enumerate(as_completed(futures), 1):
            temas = future.result()
            todos_temas.extend(temas)
            if i % 100 == 0:
                print(f"[INFO] Proposição {i}/{len(prop_ids)} processada")

    df = pd.DataFrame(todos_temas)
    output_path = os.path.join(RAW_DIR, f"temas_proposicoes_{ano}.csv")
    df.to_csv(output_path, index=False)
    print(f"[FINALIZADO] {len(df)} temas salvos em '{output_path}'")
    return df

# %%
df_temas = get_temas_por_proposicoes(2023)
df_temas.head()
# Out:
# [INICIANDO] Coleta de temas das proposições do ano 2023...
# [INFO] Proposição 100/22900 processada
# [INFO] Proposição 200/22900 processada
# [INFO] Proposição 300/22900 processada
# [INFO] Proposição 400/22900 processada
# [INFO] Proposição 500/22900 processada
# [INFO] Proposição 600/22900 processada
# [INFO] Proposição 700/22900 processada
# [INFO] Proposição 800/22900 processada
# [INFO] Proposição 900/22900 processada
# [INFO] Proposição 1000/22900 processada
# [INFO] Proposição 1100/22900 processada
# [INFO] Proposição 1200/22900 processada
# [INFO] Proposição 1300/22900 processada
# [INFO] Proposição 1400/22900 processada
# [INFO] Proposição 1500/22900 processada
# [INFO] Proposição 1600/22900 processada
# [INFO] Proposição 1700/22900 processada
# [INFO] Proposição 1800/22900 processada
# [INFO] Proposição 1900/22900 processada
# [INFO] Proposição 2000/22900 processada
# [INFO] Proposição 2100/22900 processada
# [INFO] Proposição 2200/22900 processada
# [INFO] Proposição 2300/22900 processada
# [INFO] Proposição 2400/22900 processada
# [INFO] Proposição 2500/22900 processada
# [INFO] Proposição 2600/22900 processada
# [INFO] Proposição 2700/22900 processada
# [ERRO] Status 503 - https://dadosabertos.camara.leg.br/api/v2/proposicoes/2351209/temas
# [INFO] Proposição 2800/22900 processada
# [INFO] Proposição 2900/22900 processada
# [INFO] Proposição 3000/22900 processada
# [INFO] Proposição 3100/22900 processada
# [INFO] Proposição 3200/22900 processada
# [INFO] Proposição 3300/22900 processada
# [INFO] Proposição 3400/22900 processada
# [INFO] Proposição 3500/22900 processada
# [INFO] Proposição 3600/22900 processada
# [INFO] Proposição 3700/22900 processada
# [INFO] Proposição 3800/22900 processada
# [INFO] Proposição 3900/22900 processada
# [INFO] Proposição 4000/22900 processada
# [INFO] Proposição 4100/22900 processada
# [INFO] Proposição 4200/22900 processada
# [INFO] Proposição 4300/22900 processada
# [INFO] Proposição 4400/22900 processada
# [INFO] Proposição 4500/22900 processada
# [INFO] Proposição 4600/22900 processada
# [INFO] Proposição 4700/22900 processada
# [INFO] Proposição 4800/22900 processada
# [INFO] Proposição 4900/22900 processada
# [INFO] Proposição 5000/22900 processada
# [INFO] Proposição 5100/22900 processada
# [INFO] Proposição 5200/22900 processada
# [INFO] Proposição 5300/22900 processada
# [INFO] Proposição 5400/22900 processada
# [INFO] Proposição 5500/22900 processada
# [INFO] Proposição 5600/22900 processada
# [INFO] Proposição 5700/22900 processada
# [INFO] Proposição 5800/22900 processada
# [INFO] Proposição 5900/22900 processada
# [INFO] Proposição 6000/22900 processada
# [INFO] Proposição 6100/22900 processada
# [INFO] Proposição 6200/22900 processada
# [INFO] Proposição 6300/22900 processada
# [INFO] Proposição 6400/22900 processada
# [INFO] Proposição 6500/22900 processada
# [INFO] Proposição 6600/22900 processada
# [INFO] Proposição 6700/22900 processada
# [INFO] Proposição 6800/22900 processada
# [INFO] Proposição 6900/22900 processada
# [INFO] Proposição 7000/22900 processada
# [INFO] Proposição 7100/22900 processada
# [INFO] Proposição 7200/22900 processada
# [INFO] Proposição 7300/22900 processada
# [INFO] Proposição 7400/22900 processada
# [INFO] Proposição 7500/22900 processada
# [INFO] Proposição 7600/22900 processada
# [INFO] Proposição 7700/22900 processada
# [INFO] Proposição 7800/22900 processada
# [INFO] Proposição 7900/22900 processada
# [INFO] Proposição 8000/22900 processada
# [INFO] Proposição 8100/22900 processada
# [INFO] Proposição 8200/22900 processada
# [INFO] Proposição 8300/22900 processada
# [INFO] Proposição 8400/22900 processada
# [INFO] Proposição 8500/22900 processada
# [INFO] Proposição 8600/22900 processada
# [INFO] Proposição 8700/22900 processada
# [INFO] Proposição 8800/22900 processada
# [INFO] Proposição 8900/22900 processada
# [INFO] Proposição 9000/22900 processada
# [INFO] Proposição 9100/22900 processada
# [INFO] Proposição 9200/22900 processada
# [INFO] Proposição 9300/22900 processada
# [INFO] Proposição 9400/22900 processada
# [INFO] Proposição 9500/22900 processada
# [INFO] Proposição 9600/22900 processada
# [INFO] Proposição 9700/22900 processada
# [INFO] Proposição 9800/22900 processada
# [INFO] Proposição 9900/22900 processada
# [INFO] Proposição 10000/22900 processada
# [INFO] Proposição 10100/22900 processada
# [INFO] Proposição 10200/22900 processada
# [INFO] Proposição 10300/22900 processada
# [INFO] Proposição 10400/22900 processada
# [INFO] Proposição 10500/22900 processada
# [INFO] Proposição 10600/22900 processada
# [INFO] Proposição 10700/22900 processada
# [INFO] Proposição 10800/22900 processada
# [INFO] Proposição 10900/22900 processada
# [INFO] Proposição 11000/22900 processada
# [INFO] Proposição 11100/22900 processada
# [INFO] Proposição 11200/22900 processada
# [INFO] Proposição 11300/22900 processada
# [INFO] Proposição 11400/22900 processada
# [INFO] Proposição 11500/22900 processada
# [INFO] Proposição 11600/22900 processada
# [INFO] Proposição 11700/22900 processada
# [INFO] Proposição 11800/22900 processada
# [INFO] Proposição 11900/22900 processada
# [INFO] Proposição 12000/22900 processada
# [INFO] Proposição 12100/22900 processada
# [INFO] Proposição 12200/22900 processada
# [INFO] Proposição 12300/22900 processada
# [INFO] Proposição 12400/22900 processada
# [INFO] Proposição 12500/22900 processada
# [INFO] Proposição 12600/22900 processada
# [INFO] Proposição 12700/22900 processada
# [INFO] Proposição 12800/22900 processada
# [INFO] Proposição 12900/22900 processada
# [INFO] Proposição 13000/22900 processada
# [INFO] Proposição 13100/22900 processada
# [INFO] Proposição 13200/22900 processada
# [INFO] Proposição 13300/22900 processada
# [INFO] Proposição 13400/22900 processada
# [INFO] Proposição 13500/22900 processada
# [INFO] Proposição 13600/22900 processada
# [INFO] Proposição 13700/22900 processada
# [INFO] Proposição 13800/22900 processada
# [INFO] Proposição 13900/22900 processada
# [INFO] Proposição 14000/22900 processada
# [INFO] Proposição 14100/22900 processada
# [INFO] Proposição 14200/22900 processada
# [INFO] Proposição 14300/22900 processada
# [INFO] Proposição 14400/22900 processada
# [INFO] Proposição 14500/22900 processada
# [INFO] Proposição 14600/22900 processada
# [INFO] Proposição 14700/22900 processada
# [INFO] Proposição 14800/22900 processada
# [INFO] Proposição 14900/22900 processada
# [INFO] Proposição 15000/22900 processada
# [INFO] Proposição 15100/22900 processada
# [INFO] Proposição 15200/22900 processada
# [INFO] Proposição 15300/22900 processada
# [INFO] Proposição 15400/22900 processada
# [INFO] Proposição 15500/22900 processada
# [INFO] Proposição 15600/22900 processada
# [INFO] Proposição 15700/22900 processada
# [INFO] Proposição 15800/22900 processada
# [INFO] Proposição 15900/22900 processada
# [INFO] Proposição 16000/22900 processada
# [INFO] Proposição 16100/22900 processada
# [INFO] Proposição 16200/22900 processada
# [INFO] Proposição 16300/22900 processada
# [INFO] Proposição 16400/22900 processada
# [INFO] Proposição 16500/22900 processada
# [INFO] Proposição 16600/22900 processada
# [INFO] Proposição 16700/22900 processada
# [INFO] Proposição 16800/22900 processada
# [INFO] Proposição 16900/22900 processada
# [INFO] Proposição 17000/22900 processada
# [INFO] Proposição 17100/22900 processada
# [INFO] Proposição 17200/22900 processada
# [INFO] Proposição 17300/22900 processada
# [INFO] Proposição 17400/22900 processada
# [INFO] Proposição 17500/22900 processada
# [INFO] Proposição 17600/22900 processada
# [INFO] Proposição 17700/22900 processada
# [INFO] Proposição 17800/22900 processada
# [INFO] Proposição 17900/22900 processada
# [INFO] Proposição 18000/22900 processada
# [INFO] Proposição 18100/22900 processada
# [INFO] Proposição 18200/22900 processada
# [INFO] Proposição 18300/22900 processada
# [INFO] Proposição 18400/22900 processada
# [INFO] Proposição 18500/22900 processada
# [ERRO] Status 503 - https://dadosabertos.camara.leg.br/api/v2/proposicoes/2385952/temas
# [INFO] Proposição 18600/22900 processada
# [INFO] Proposição 18700/22900 processada
# [INFO] Proposição 18800/22900 processada
# [INFO] Proposição 18900/22900 processada
# [INFO] Proposição 19000/22900 processada
# [INFO] Proposição 19100/22900 processada
# [INFO] Proposição 19200/22900 processada
# [INFO] Proposição 19300/22900 processada
# [INFO] Proposição 19400/22900 processada
# [INFO] Proposição 19500/22900 processada
# [INFO] Proposição 19600/22900 processada
# [INFO] Proposição 19700/22900 processada
# [INFO] Proposição 19800/22900 processada
# [INFO] Proposição 19900/22900 processada
# [INFO] Proposição 20000/22900 processada
# [INFO] Proposição 20100/22900 processada
# [INFO] Proposição 20200/22900 processada
# [INFO] Proposição 20300/22900 processada
# [INFO] Proposição 20400/22900 processada
# [INFO] Proposição 20500/22900 processada
# [INFO] Proposição 20600/22900 processada
# [INFO] Proposição 20700/22900 processada
# [INFO] Proposição 20800/22900 processada
# [INFO] Proposição 20900/22900 processada
# [INFO] Proposição 21000/22900 processada
# [INFO] Proposição 21100/22900 processada
# [INFO] Proposição 21200/22900 processada
# [INFO] Proposição 21300/22900 processada
# [INFO] Proposição 21400/22900 processada
# [INFO] Proposição 21500/22900 processada
# [INFO] Proposição 21600/22900 processada
# [INFO] Proposição 21700/22900 processada
# [INFO] Proposição 21800/22900 processada
# [INFO] Proposição 21900/22900 processada
# [INFO] Proposição 22000/22900 processada
# [INFO] Proposição 22100/22900 processada
# [INFO] Proposição 22200/22900 processada
# [INFO] Proposição 22300/22900 processada
# [INFO] Proposição 22400/22900 processada
# [INFO] Proposição 22500/22900 processada
# [INFO] Proposição 22600/22900 processada
# [INFO] Proposição 22700/22900 processada
# [INFO] Proposição 22800/22900 processada
# [INFO] Proposição 22900/22900 processada
# [FINALIZADO] 18251 temas salvos em 'dados/raw\temas_proposicoes_2023.csv'
#    codTema                              tema  relevancia  id_proposicao
# 0       34             Administração Pública           0        2345485
# 1       52  Previdência e Assistência Social           0        2074843
# 2       56                             Saúde           0        2074843
# 3       57                Defesa e Segurança           0        1198010
# 4       72  Homenagens e Datas Comemorativas           0         618609
